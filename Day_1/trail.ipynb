# %%
x=[1,2, 3]
print(type(x))
# Out:
# <class 'list'>

# %%
d={"name":"Stavina"}
d["name"]="abc"
print(d)
# Out:
# {'name': 'abc'}

# %%
t=()
print(type(t))
# Out:
# <class 'tuple'>

# %% [markdown]
# Set and List
# Both are mutable
# Set can have different data types

# %%
x={1,2,2,3}
print(len(x))
# Out:
# 3

# %% [markdown]
# ### What are keywords in python?
# - reserved words
# - special purpose
# - cannot be used as a varialble
# - eg: pass, return, print

# %%
assert 11==11
